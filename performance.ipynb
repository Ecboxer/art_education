# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('resources/school-ela-results-2013-18-ALL.csv', skiprows=7)
df.head()
# Out:
#                 Unnamed: 0     DBN                School Name Grade  Year  \
# 0  01M01532013All Students  01M015  P.S. 015 Roberto Clemente     3  2013
# 1  01M01532014All Students  01M015  P.S. 015 Roberto Clemente     3  2014
# 2  01M01532015All Students  01M015  P.S. 015 Roberto Clemente     3  2015
# 3  01M01532016All Students  01M015  P.S. 015 Roberto Clemente     3  2016
# 4  01M01532017All Students  01M015  P.S. 015 Roberto Clemente     3  2017
#
#        Category  Number Tested Mean Scale Score   #     % #.1   %.1 #.2   %.2  \
# 0  All Students             27              289  14  51.9  11  40.7   2   7.4
# 1  All Students             18              285  10  55.6   8  44.4   0   0.0
# 2  All Students             16              282   9  56.3   5  31.3   2  12.5
# 3  All Students             20              293  10  50.0   6  30.0   4  20.0
# 4  All Students             27              302  10  37.0   8  29.6   7  25.9
#
#   #.3  %.3 #.4   %.4
# 0   0  0.0   2   7.4
# ...

# %% [markdown]
# Rename the columns for easier access.

# %%
new_cols = ['sort', 'dbn', 'school_name', 'grade', 'year', 'category', 'num_tested', 'mean_score', 'num_1', 'perc_1', 'num_2', 'perc_2', 'num_3', 'perc_3', 'num_4', 'perc_4', 'num_34', 'perc_34']
cols_map = {df.columns[i]: new_cols[i] for i in range(len(df.columns))}
df.rename(index=str, columns=cols_map, inplace=True)
df.head()
# Out:
#                       sort     dbn                school_name grade  year  \
# 0  01M01532013All Students  01M015  P.S. 015 Roberto Clemente     3  2013
# 1  01M01532014All Students  01M015  P.S. 015 Roberto Clemente     3  2014
# 2  01M01532015All Students  01M015  P.S. 015 Roberto Clemente     3  2015
# 3  01M01532016All Students  01M015  P.S. 015 Roberto Clemente     3  2016
# 4  01M01532017All Students  01M015  P.S. 015 Roberto Clemente     3  2017
#
#        category  num_tested mean_score num_1 perc_1 num_2 perc_2 num_3 perc_3  \
# 0  All Students          27        289    14   51.9    11   40.7     2    7.4
# 1  All Students          18        285    10   55.6     8   44.4     0    0.0
# 2  All Students          16        282     9   56.3     5   31.3     2   12.5
# 3  All Students          20        293    10   50.0     6   30.0     4   20.0
# 4  All Students          27        302    10   37.0     8   29.6     7   25.9
#
#   num_4 perc_4 num_34 perc_34
# ...

# %% [markdown]
# No missing data

# %%
df.shape[0] - df.count()
# Out:
# sort           0
# dbn            0
# school_name    0
# grade          0
# year           0
# category       0
# num_tested     0
# mean_score     0
# num_1          0
# perc_1         0
# num_2          0
# perc_2         0
# num_3          0
# perc_3         0
# num_4          0
# perc_4         0
# num_34         0
# perc_34        0
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# Create a dataframe for each year, and join them on dbn

# %%
df.unstack('grade')
# Out:
# sort     0                 01M01532013All Students
#          1                 01M01532014All Students
#          2                 01M01532015All Students
#          3                 01M01532016All Students
#          4                 01M01532017All Students
#          5                 01M01532018All Students
#          6                 01M01542013All Students
#          7                 01M01542014All Students
#          8                 01M01542015All Students
#          9                 01M01542016All Students
#          10                01M01542017All Students
#          11                01M01542018All Students
#          12                01M01552013All Students
#          13                01M01552014All Students
#          14                01M01552015All Students
#          15                01M01552016All Students
#          16                01M01552017All Students
#          17                01M01552018All Students
# ...

# %%
temp_ind = temp.set_index(['grade', 'year'])
temp_ind = temp_ind.unstack(['grade', 'year'])
temp_ind
# Out:
#          grade       year
# sort     3           2013             01M01532013All Students
#                      2014             01M01532014All Students
#                      2015             01M01532015All Students
#                      2016             01M01532016All Students
#                      2017             01M01532017All Students
#                      2018             01M01532018All Students
#          4           2013             01M01542013All Students
#                      2014             01M01542014All Students
#                      2015             01M01542015All Students
#                      2016             01M01542016All Students
#                      2017             01M01542017All Students
#                      2018             01M01542018All Students
#          5           2013             01M01552013All Students
#                      2014             01M01552014All Students
#                      2015             01M01552015All Students
# ...

# %%
temp = df[df['dbn'] == '01M015']
temp
# Out:
#                                 sort     dbn                school_name  \
# 0            01M01532013All Students  01M015  P.S. 015 Roberto Clemente
# 1            01M01532014All Students  01M015  P.S. 015 Roberto Clemente
# 2            01M01532015All Students  01M015  P.S. 015 Roberto Clemente
# 3            01M01532016All Students  01M015  P.S. 015 Roberto Clemente
# 4            01M01532017All Students  01M015  P.S. 015 Roberto Clemente
# 5            01M01532018All Students  01M015  P.S. 015 Roberto Clemente
# 6            01M01542013All Students  01M015  P.S. 015 Roberto Clemente
# 7            01M01542014All Students  01M015  P.S. 015 Roberto Clemente
# 8            01M01542015All Students  01M015  P.S. 015 Roberto Clemente
# 9            01M01542016All Students  01M015  P.S. 015 Roberto Clemente
# 10           01M01542017All Students  01M015  P.S. 015 Roberto Clemente
# 11           01M01542018All Students  01M015  P.S. 015 Roberto Clemente
# ...
